# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('clear_data.csv')

# %%
df.head(3)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#    discounted_price  actual_price  discount_percentage  rating  rating_count  \
# 0             399.0        1099.0                 64.0     4.2         24269
# 1             199.0         349.0                 43.0     4.0         43994
# 2             199.0        1899.0                 90.0     3.9          7928
#
#            category_main             category_sub type_product  \
# 0  Computers&Accessories  Accessories&Peripherals    USBCables
# 1  Computers&Accessories  Accessories&Peripherals    USBCables
# 2  Computers&Accessories  Accessories&Peripherals    USBCables
#
#                                              user_id
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...

# %%
df.dtypes[1:30]
# Out:
# product_name            object
# discounted_price       float64
# actual_price           float64
# discount_percentage    float64
# rating                 float64
# rating_count             int64
# category_main           object
# category_sub            object
# type_product            object
# user_id                 object
# dtype: object

# %%
df.describe()  #выведем описательную статистику
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1465.000000    1465.000000          1465.000000  1465.000000
# mean        3125.310874    5444.990635            47.691468     4.096519
# std         6944.304394   10874.826864            21.635905     0.291585
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000            32.000000     4.000000
# 50%          799.000000    1650.000000            50.000000     4.100000
# 75%         1999.000000    4295.000000            63.000000     4.300000
# max        77990.000000  139900.000000            94.000000     5.000000
#
#         rating_count
# count    1465.000000
# mean    18270.596587
# std     42729.981606
# min         0.000000
# 25%      1173.000000
# 50%      5178.000000
# 75%     17325.000000
# max    426973.000000

# %%
sns.pairplot(df, corner = True)
# Out:
# C:\Python\ve\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Для анализа берем пары с наиболее видимой корреляцией

# %%
df1 = df[(~df['discounted_price'].isna()) &  (~df['actual_price'].isna())  &  (~df['discount_percentage'].isna()) &  (~df['rating'].isna())&  (~df['rating_count'].isna())][['discounted_price', 'actual_price', 'discount_percentage','rating', 'rating_count']]
df1
# Out:
#       discounted_price  actual_price  discount_percentage  rating  \
# 0                399.0        1099.0                 64.0     4.2
# 1                199.0         349.0                 43.0     4.0
# 2                199.0        1899.0                 90.0     3.9
# 3                329.0         699.0                 53.0     4.2
# 4                154.0         399.0                 61.0     4.2
# ...                ...           ...                  ...     ...
# 1460             379.0         919.0                 59.0     4.0
# 1461            2280.0        3045.0                 25.0     4.1
# 1462            2219.0        3080.0                 28.0     3.6
# 1463            1399.0        1890.0                 26.0     4.0
# 1464            2863.0        3690.0                 22.0     4.3
#
#       rating_count
# 0            24269
# 1            43994
# 2             7928
# 3            94363
# 4            16905
# ...            ...
# 1460          1090
# 1461          4118
# 1462           468
# 1463          8031
# 1464          6987
#
# [1465 rows x 5 columns]

# %%
sns.pairplot(df1, corner=True)
# Out:
# C:\Python\ve\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Самая сильная пооложительная корреляция наблюдается у актуальная цена/дисконтная цена - что логично

# %%
df1.corr() #рассчитаем коэффициент корреляции
# Out:
#                      discounted_price  actual_price  discount_percentage  \
# discounted_price             1.000000      0.961915            -0.242412
# actual_price                 0.961915      1.000000            -0.118098
# discount_percentage         -0.242412     -0.118098             1.000000
# rating                       0.120365      0.121695            -0.154924
# rating_count                -0.027010     -0.035890             0.010869
#
#                        rating  rating_count
# discounted_price     0.120365     -0.027010
# actual_price         0.121695     -0.035890
# discount_percentage -0.154924      0.010869
# rating               1.000000      0.101663
# rating_count         0.101663      1.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   discounted_price     1465 non-null   float64
#  1   actual_price         1465 non-null   float64
#  2   discount_percentage  1465 non-null   float64
#  3   rating               1465 non-null   float64
#  4   rating_count         1465 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 57.4 KB

# %% [markdown]
# Построим Heatmap

# %%
sns.heatmap(df1.corr(),  annot=True)
# Out:
# <Axes: >

# %%
df2 = df1[['actual_price','rating']]
df2
# Out:
#       actual_price  rating
# 0           1099.0     4.2
# 1            349.0     4.0
# 2           1899.0     3.9
# 3            699.0     4.2
# 4            399.0     4.2
# ...            ...     ...
# 1460         919.0     4.0
# 1461        3045.0     4.1
# 1462        3080.0     3.6
# 1463        1890.0     4.0
# 1464        3690.0     4.3
#
# [1465 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
x = np.array([df2['actual_price']]).reshape((-1, 1))
x
# Out:
# array([[1099.],
#        [ 349.],
#        [1899.],
#        ...,
#        [3080.],
#        [1890.],
#        [3690.]])

# %%
y = df2['rating']

# %%
lm = LinearRegression()

# %%
model = lm.fit(x, y)

# %%
model.predict([[1]]) #предсказание
# Out:
# array([4.07875502])

# %%
print(f'alpha = {model.intercept_}')
print(f'betas = {model.coef_}')
# Out:
# alpha = 4.0787517534962
# betas = [3.26300246e-06]

# %%
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.014809761228242069

# %%
import matplotlib.pyplot as plt

# %%
y_hat = model.predict(x)
y_hat
# Out:
# array([4.08233779, 4.07989054, 4.0849482 , ..., 4.0888018 , 4.08491883,
#        4.09079223])

# %%
ax = sns.scatterplot(df2, y='rating', x='actual_price')
ax.plot(x,y_hat, color = 'r')
plt.legend(['data', 'model'])

# %%
df[df.actual_price>100000]
# Out:
#      product_id                                       product_name  \
# 249  B09WN3SRC7  Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...
#
#      discounted_price  actual_price  discount_percentage  rating  \
# 249           77990.0      139900.0                 44.0     4.7
#
#      rating_count                                            user_id  \
# 249          5935  AF6Z2OYIXRPZJHVYN2MFKKYHPHFQ,AH5SAORYVUN5MGIBL...
#
#       category_1            category_2     type_category
# 249  Electronics  HomeTheater,TV&Video  SmartTelevisions

# %%
df[df.rating<3]
# Out:
#       product_id                                       product_name  \
# 545   B0BBVKRP7B  SHREENOVA ID116 Plus Bluetooth Fitness Smart W...
# 1243  B0BFBNXS94  Personal Size Blender, Portable Blender, Batte...
# 1286  B0BNDGL26T  MR. BRAND Portable USB Juicer Electric USB Jui...
# 1309  B0BPJBTB3F  Khaitan ORFin Fan heater for Home and kitchen-...
# 1356  B0B7L86YCB  Green Tales Heat Seal Mini Food Sealer-Impulse...
# 1449  B0BBLHTRM9  IONIX Tap filter Multilayer | Activated Carbon...
#
#       discounted_price  actual_price  discount_percentage  rating  \
# 545              281.0        1999.0                 86.0     2.8
# 1243             669.0        1499.0                 55.0     2.3
# 1286             499.0        2199.0                 77.0     2.8
# 1309            1299.0        2495.0                 48.0     2.0
# 1356             161.0         300.0                 46.0     2.6
# 1449             199.0         699.0                 72.0     2.9
#
#       rating_count category_main                category_sub  \
# 545             87   Electronics          WearableTechnology
# 1243            13  Home&Kitchen      Kitchen&HomeAppliances
# 1286           109  Home&Kitchen      Kitchen&HomeAppliances
# 1309             2  Home&Kitchen  Heating,Cooling&AirQuality
# 1356            24  Home&Kitchen      Kitchen&HomeAppliances
# 1449           159  Home&Kitchen      Kitchen&HomeAppliances
#
#                   type_product  \
# 545               SmartWatches
# 1243              HandBlenders
# 1286       JuicerMixerGrinders
# 1309                FanHeaters
# 1356             VacuumSealers
# 1449  WaterPurifierAccessories
#
#                                                 user_id
# 545   AHSYI7EUDN2RNS2IPMGAS5MKLXPQ,AHHLJNBYVOGQSFG2Q...
# 1243  AHRDA66XO63XYCBZJMW4EUJN3BFQ,AELE2SOO7LBNHXU7U...
# 1286  AEJKHGA26MUVUZIYWZOW4B6I4X7Q,AF3B47EOSBULYG63E...
# 1309  AGHT3K4KSG5MAQUSXRDT5VNB73GA,AE4Q5XQ7SZW35EEUJ...
# 1356  AG2BB3Q2AQB7SBFBURGYSMFHDAOA,AGFXIO346VXYI35AN...
# 1449  AF6LRVDRKYWPTZXZLQERZ3LXCWDA,AG7FU75LA5ONPMNEV...

# %%
Построим гистограмму распределения скидки

# %%
df.discount_percentage.hist(bins = 90)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'discounted_price', 'actual_price',
#        'discount_percentage', 'rating', 'rating_count', 'category_main',
#        'category_sub', 'type_product', 'user_id'],
#       dtype='object')

# %%
df['category_main'].unique()
# Out:
# array(['Computers&Accessories', 'Electronics', 'MusicalInstruments',
#        'OfficeProducts', 'Home&Kitchen', 'HomeImprovement', 'Toys&Games',
#        'Car&Motorbike', 'Health&PersonalCare'], dtype=object)

# %%
#анализ распределения продуктов по главной категории
category_counts= df['category_main'].value_counts()
category_counts.values
# Out:
# array([526, 453, 448,  31,   2,   2,   1,   1,   1], dtype=int64)

# %%
plt.barh( category_counts.index, category_counts.values)
plt.xlabel('Количество товаров')
plt.title('Распределение товаров по главной категории')
plt.gca().invert_yaxis()
for i, v in enumerate(category_counts):
    plt.text(v - 35 if v > 100 else v-25 if v > 10 else v + 3, i + 0.1, str(v), color='black', fontweight='bold')
plt.show()

# %% [markdown]
# В тройку лидеров входят «Электроника», «Компьютеры и аксессуары» и «Дом и кухня». Далее следуют Товары для офисса.
# Данные категории популярны среди клиентов.
# Количество товаров в остальных основных категориях достаточно низкое, что говорит о том, что спрос на эти товары небольшой.
# Данная информация может помочь компании понять текущие тенденции рынка и определить потенциальные возможности для роста в конкретных категориях.

# %%
subcategory_counts= df['category_sub'].value_counts()
subcategory_counts=subcategory_counts[:16]
subcategory_counts
# Out:
# category_sub
# Accessories&Peripherals                    381
# Kitchen&HomeAppliances                     308
# HomeTheater,TV&Video                       162
# Mobiles&Accessories                        161
# Heating,Cooling&AirQuality                 116
# WearableTechnology                          76
# Headphones,Earbuds&Accessories              66
# NetworkingDevices                           34
# OfficePaperProducts                         27
# ExternalDevices&DataStorage                 18
# Cameras&Photography                         16
# HomeStorage&Organization                    16
# HomeAudio                                   16
# GeneralPurposeBatteries&BatteryChargers     14
# Accessories                                 14
# Printers,Inks&Accessories                   11
# Name: count, dtype: int64

# %%
plt.barh( subcategory_counts.index, subcategory_counts.values, color='green')
plt.xlabel('Количество товаров')
plt.title('Распределение товаров по субкатегории')
plt.gca().invert_yaxis()
for i, v in enumerate(subcategory_counts):
    plt.text(v - 25 if v > 100 else v-20 if v > 20 else v + 3, i + 0.1, str(v), color='black', fontweight='bold')
plt.show()

# %%
type_product_counts= df['type_product'].value_counts()
type_product_counts=type_product_counts[:30]
type_product_counts
# Out:
# type_product
# USBCables                   233
# SmartWatches                 76
# Smartphones                  68
# SmartTelevisions             63
# In-Ear                       52
# RemoteControls               49
# MixerGrinders                27
# HDMICables                   24
# DryIrons                     24
# Mice                         24
# InstantWaterHeaters          23
# LintShavers                  22
# FanHeaters                   20
# ElectricHeaters              20
# ElectricKettles              19
# HandBlenders                 19
# WirelessUSBAdapters          18
# WallChargers                 16
# Lapdesks                     14
# LaundryBaskets               13
# MicroSD                      13
# Kettle&ToasterSets           13
# SteamIrons                   12
# JuicerMixerGrinders          12
# WaterFilters&Purifiers       12
# ScreenProtectors             12
# StorageWaterHeaters          12
# PowerBanks                   12
# SandwichMakers               11
# WaterPurifierAccessories     11
# Name: count, dtype: int64

# %%
plt.barh( type_product_counts.index, type_product_counts.values, color='orange')
plt.xlabel('Количество товаров')
plt.title('Распределение самых востребованных товаров')
plt.gca().invert_yaxis()
plt.yticks(range(len(type_product_counts)), '')
for i, v in enumerate(type_product_counts):
    plt.text(v - 25 if v > 100 else  v + 3, i + 0.1, str(v), color='black',  size = 7)
plt.show()

top_product = pd.DataFrame({'Топ товары': type_product_counts.index, 'Количество товаров': type_product_counts.values})
print('Топ 30 товаров:')
print(top_product.to_string(index=False))
# Out:
# Топ 30 товаров:
#               Топ товары  Количество товаров
#                USBCables                 233
#             SmartWatches                  76
#              Smartphones                  68
#         SmartTelevisions                  63
#                   In-Ear                  52
#           RemoteControls                  49
#            MixerGrinders                  27
#               HDMICables                  24
#                 DryIrons                  24
#                     Mice                  24
#      InstantWaterHeaters                  23
#              LintShavers                  22
#               FanHeaters                  20
#          ElectricHeaters                  20
#          ElectricKettles                  19
#             HandBlenders                  19
#      WirelessUSBAdapters                  18
#             WallChargers                  16
#                 Lapdesks                  14
#           LaundryBaskets                  13
#                  MicroSD                  13
#       Kettle&ToasterSets                  13
#               SteamIrons                  12
#      JuicerMixerGrinders                  12
#   WaterFilters&Purifiers                  12
#         ScreenProtectors                  12
#      StorageWaterHeaters                  12
#               PowerBanks                  12
#           SandwichMakers                  11
# WaterPurifierAccessories                  11

# %% [markdown]
# В первые шесть популярных товаров относятся USB-кабели, умные часы, смартфоны, умные телевизоры, наушники-вкладыши и пульты дистанционного управления.Это самые популярные подкатегории, и компании могут сосредоточиться на предоставлении продуктов этих категорий для привлечения клиентов.
#
#  Другие популярные подкатегории включают миксеры-измельчители, кабели HDMI, сухие утюги, мыши и проточные водонагреватели.Возможно, эти подкатегории менее популярны, чем первые шесть, но в них по-прежнему присутствует значительное количество товаров,
# что свидетельствует о наличии спроса на них.
#
# Данные показывают, что в топ-30 входят разнообразные товары, включая кухонную технику, бытовую электронику и личные аксессуары.Это подчеркивает важность предложения разнообразных продуктов для удовлетворения различных потребностей и предпочтений клиентов.
#
# В целом, данные могут помочь компаниям определить наиболее популярные товары и скорректировать свои продуктовые предложения в соответствии с потребительским спросом. Сосредоточив внимание на этих товарач, компании могут увеличить свои продажи и повысить свою конкурентоспособность на рынке.

# %% [markdown]
# АВС - анализ

# %%
a = df.groupby('type_product').agg({'discounted_price':sum})

# %%
a
# Out:
#                         discounted_price
# type_product
# 3DGlasses                        2699.00
# AVReceivers&Amplifiers           1990.00
# Adapters                          449.00
# Adapters&Multi-Outlets            425.00
# AirFryers                       31382.00
# ...                                  ...
# WetGrinders                      7367.66
# WireboundNotebooks                565.00
# WirelessUSBAdapters             12998.00
# WoodenPencils                      99.00
# YogurtMakers                      587.00
#
# [207 rows x 1 columns]

# %%
groupped_df=(a['discounted_price']/sum(a['discounted_price'])).sort_values(ascending=False)
groupped_df
# Out:
# type_product
# SmartTelevisions          0.341794
# Smartphones               0.233981
# SmartWatches              0.038837
# WaterFilters&Purifiers    0.018386
# USBCables                 0.018357
#                             ...
# WoodenPencils             0.000022
# ColouredPaper             0.000022
# Earpads                   0.000022
# Pens                      0.000020
# Shower&WallMounts         0.000019
# Name: discounted_price, Length: 207, dtype: float64

# %%
groupped_df = groupped_df.cumsum().reset_index()
groupped_df
# Out:
#                type_product  discounted_price
# 0          SmartTelevisions          0.341794
# 1               Smartphones          0.575775
# 2              SmartWatches          0.614612
# 3    WaterFilters&Purifiers          0.632998
# 4                 USBCables          0.651355
# ..                      ...               ...
# 202           WoodenPencils          0.999918
# 203           ColouredPaper          0.999939
# 204                 Earpads          0.999961
# 205                    Pens          0.999981
# 206       Shower&WallMounts          1.000000
#
# [207 rows x 2 columns]

# %%
groupped_df['ABC']=np.where(groupped_df['discounted_price']<0.8,'A',np.where(groupped_df['discounted_price']<0.95,'B','C'))

# %%
groupped_df[groupped_df['ABC']== 'A']
# Out:
#                    type_product  discounted_price ABC
# 0              SmartTelevisions          0.341794   A
# 1                   Smartphones          0.575775   A
# 2                  SmartWatches          0.614612   A
# 3        WaterFilters&Purifiers          0.632998   A
# 4                     USBCables          0.651355   A
# 5                 MixerGrinders          0.669074   A
# 6           StorageWaterHeaters          0.685647   A
# 7           InstantWaterHeaters          0.697714   A
# 8                        In-Ear          0.708801   A
# 9                    FanHeaters          0.719591   A
# 10             HEPAAirPurifiers          0.730002   A
# 11               RoboticVacuums          0.740245   A
# 12          StandardTelevisions          0.749655   A
# 13  Split-SystemAirConditioners          0.759044   A
# 14              ElectricHeaters          0.767768   A
# 15           TraditionalLaptops          0.775903   A
# 16                   SteamIrons          0.783953   A
# 17               Wet-DryVacuums          0.791352   A
# 18          JuicerMixerGrinders          0.798546   A

# %%
Товары которые приносят наибольшую прибыль 80%
